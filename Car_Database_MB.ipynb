# %%
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
connection = sqlite3.connect('Car_Database.db')

# %%
df = pd.read_sql_query('SELECT * FROM Car_Options WHERE (engine_id = 1 OR engine_id = 2)', connection)

# %%
df
# Out:
#     option_set_id  model_id  engine_id  transmission_id  chassis_id  \
# 0               1         4          2                4           6
# 1               2         5          2                4           6
# 2               3         6          1                4           7
# 3               4        15          1                4           7
# 4               5        14          2                4           7
# 5               6        16          2                4           7
# 6               8        10          1                4           6
# 7               9        11          2                4           6
# 8              10        12          2                4           7
# 9              11        13          1                4           7
# 10             12         1          1                4           7
# 11             13         2          1                4           7
# 12             14         3          1                4           6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   option_set_id     23 non-null     int64
#  1   model_id          23 non-null     int64
#  2   engine_id         23 non-null     int64
#  3   transmission_id   23 non-null     int64
#  4   chassis_id        23 non-null     int64
#  5   premium_sound_id  10 non-null     float64
#  6   color             23 non-null     object
#  7   option_set_price  23 non-null     int64
# dtypes: float64(1), int64(6), object(1)
# memory usage: 1.6+ KB

# %%
connection.close()

# %%
plt.figure(figsize=(15,10))
sns.scatterplot(data=df, x='color', y='option_set_price', hue='color', palette='dark', s=400)
plt.title('Distribution of Option Prices by Car Color', fontsize=32)
plt.xlabel('Car color', fontsize=20)
plt.ylabel('Option price', fontsize=20)
plt.tight_layout()
plt.show()
